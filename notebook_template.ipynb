# %%
"""Template for .ipynb files
Adapted from Florian Wilhelm's blog post "Working efficiently with JupyterLab
Notebooks", Nov. 08, 2018 (accessed Dec. 12, 2025)
"""

import logging

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

# %load_ext autoreload
# %autoreload 2

logging.basicConfig(level=logging.INFO, stream=sys.stdout)
